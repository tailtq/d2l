# %%
from d2l import torch as d2l
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, use_1x1conv=False, stride=1, **kwargs):
        super().__init__(**kwargs)
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, stride=stride)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        if use_1x1conv:
            self.conv3 = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride)
        else:
            self.conv3 = None
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)
        
    def forward(self, X):
        Y = F.relu(self.bn1(self.conv1(X)))
        Y = self.bn2(self.conv2(Y))
        if self.conv3:
            X = self.conv3(X)
        return F.relu(Y + X)

# %%
blk = ResidualBlock(3, 3)
X = torch.rand(size=(4, 3, 6, 6))
blk(X).shape
# Out:
# torch.Size([4, 3, 6, 6])

# %%
blk = ResidualBlock(3, 6, use_1x1conv=True, stride=2)
blk(X).shape
# Out:
# torch.Size([4, 6, 3, 3])

# %%
# Out:
# tensor([[[[0.3192, 0.7543, 0.7524, 0.1057, 0.6375, 0.7714],
#           [0.2758, 0.3655, 0.1091, 0.9191, 0.9257, 0.5517],
#           [0.8287, 0.7907, 0.5358, 0.8027, 0.1735, 0.5176],
#           [0.3264, 0.0596, 0.3561, 0.6728, 0.2772, 0.0255],
#           [0.9977, 0.1335, 0.9940, 0.7991, 0.3089, 0.8546],
#           [0.7190, 0.0806, 0.2935, 0.1088, 0.5587, 0.6426]],
#
#          [[0.0505, 0.5286, 0.6906, 0.9192, 0.0605, 0.0035],
#           [0.5606, 0.8227, 0.4698, 0.5525, 0.8571, 0.0031],
#           [0.4166, 0.8401, 0.4291, 0.4696, 0.6857, 0.1742],
#           [0.1667, 0.6807, 0.9049, 0.9334, 0.7008, 0.6355],
#           [0.6085, 0.1185, 0.0343, 0.0119, 0.9306, 0.5655],
#           [0.5955, 0.6872, 0.8875, 0.4815, 0.2036, 0.9485]],
#
#          [[0.6015, 0.7476, 0.8075, 0.7672, 0.1897, 0.1044],
#           [0.8670, 0.3114, 0.2989, 0.3729, 0.7604, 0.5015],
#           [0.8457, 0.3998, 0.4948, 0.2822, 0.7239, 0.4228],
#           [0.2850, 0.5908, 0.8189, 0.3541, 0.0798, 0.1406],
#           [0.5396, 0.5243, 0.4080, 0.9403, 0.1772, 0.9840],
#           [0.6671, 0.1282, 0.7973, 0.2944, 0.7884, 0.2386]]],
#
#
#         [[[0.3134, 0.0500, 0.1416, 0.9736, 0.1369, 0.9012],
#           [0.3315, 0.0754, 0.9955, 0.1297, 0.3237, 0.7880],
#           [0.7312, 0.0862, 0.3382, 0.8142, 0.2364, 0.1752],
#           [0.0018, 0.2011, 0.1548, 0.3689, 0.2122, 0.6603],
#           [0.7267, 0.2597, 0.3228, 0.6565, 0.0861, 0.5365],
#           [0.5039, 0.7675, 0.7724, 0.7015, 0.8764, 0.7489]],
#
#          [[0.3596, 0.1711, 0.6472, 0.1307, 0.6118, 0.9949],
#           [0.6411, 0.6754, 0.0610, 0.0198, 0.1661, 0.4106],
#           [0.4298, 0.5118, 0.1066, 0.0751, 0.4257, 0.2089],
#           [0.6585, 0.4911, 0.3449, 0.0781, 0.5052, 0.8741],
#           [0.8565, 0.8036, 0.9879, 0.9663, 0.1120, 0.3843],
#           [0.2525, 0.3519, 0.9284, 0.3330, 0.9042, 0.1472]],
#
#          [[0.3560, 0.8032, 0.8312, 0.5544, 0.5119, 0.0534],
#           [0.7720, 0.1010, 0.0971, 0.1155, 0.9516, 0.2784],
#           [0.1187, 0.9509, 0.5781, 0.0213, 0.0370, 0.0803],
#           [0.3388, 0.9351, 0.1440, 0.6571, 0.8859, 0.9627],
#           [0.3846, 0.4029, 0.3484, 0.1117, 0.3907, 0.2790],
#           [0.4096, 0.8301, 0.6090, 0.8360, 0.0779, 0.5389]]],
#
#
#         [[[0.9709, 0.4504, 0.6535, 0.9014, 0.8756, 0.4249],
#           [0.4648, 0.2051, 0.3598, 0.5054, 0.9325, 0.6958],
#           [0.4497, 0.6349, 0.7025, 0.4403, 0.4846, 0.5976],
#           [0.1265, 0.7334, 0.9453, 0.9721, 0.0826, 0.0638],
#           [0.7474, 0.4601, 0.0543, 0.1715, 0.7720, 0.2227],
#           [0.9975, 0.0233, 0.9911, 0.5027, 0.4397, 0.0850]],
#
#          [[0.0046, 0.6099, 0.8824, 0.9037, 0.4350, 0.7981],
#           [0.6656, 0.7050, 0.2007, 0.8063, 0.2566, 0.5649],
#           [0.8428, 0.1389, 0.3151, 0.1801, 0.3045, 0.7289],
#           [0.6151, 0.7788, 0.4811, 0.3565, 0.1831, 0.5402],
#           [0.5096, 0.5725, 0.8517, 0.6949, 0.1797, 0.2398],
#           [0.6778, 0.1214, 0.0259, 0.5266, 0.9868, 0.8273]],
#
#          [[0.5253, 0.7158, 0.5813, 0.9781, 0.9501, 0.4620],
#           [0.8032, 0.5062, 0.4089, 0.9371, 0.1140, 0.4557],
#           [0.0244, 0.4021, 0.7813, 0.5991, 0.1262, 0.7439],
#           [0.1973, 0.0641, 0.0457, 0.0296, 0.8139, 0.5758],
#           [0.5200, 0.6881, 0.9139, 0.8765, 0.1732, 0.0198],
#           [0.8134, 0.0140, 0.3343, 0.6925, 0.3426, 0.7903]]],
#
#
#         [[[0.9482, 0.5944, 0.9625, 0.6054, 0.6854, 0.6474],
#           [0.9027, 0.9887, 0.2452, 0.1264, 0.3705, 0.3234],
#           [0.6966, 0.1460, 0.3555, 0.1384, 0.7767, 0.1045],
#           [0.2845, 0.4980, 0.7558, 0.3641, 0.9803, 0.2118],
#           [0.2076, 0.2312, 0.1188, 0.9171, 0.4608, 0.3010],
#           [0.1362, 0.1724, 0.6220, 0.5680, 0.8711, 0.2569]],
#
#          [[0.1645, 0.8058, 0.6559, 0.3439, 0.6067, 0.6759],
#           [0.8862, 0.9906, 0.7754, 0.1946, 0.9311, 0.4556],
#           [0.6780, 0.1387, 0.6456, 0.6186, 0.0877, 0.2835],
#           [0.8206, 0.7100, 0.2274, 0.5633, 0.5153, 0.3672],
#           [0.5077, 0.4639, 0.1406, 0.2204, 0.7498, 0.7736],
#           [0.9752, 0.0194, 0.9712, 0.6865, 0.0394, 0.6258]],
#
#          [[0.6788, 0.3165, 0.7411, 0.0199, 0.7195, 0.0563],
#           [0.5971, 0.0704, 0.9688, 0.3836, 0.8929, 0.9344],
#           [0.2314, 0.3135, 0.5506, 0.4398, 0.4945, 0.9430],
#           [0.9634, 0.9205, 0.9418, 0.1005, 0.0767, 0.9874],
#           [0.0437, 0.2840, 0.1695, 0.4674, 0.4721, 0.6167],
#           [0.1492, 0.9522, 0.4557, 0.9075, 0.4936, 0.4986]]]])
